# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
#%matplotlib inline
import time
import os
import warnings
warnings.filterwarnings('ignore')
from test_ppo_model import *

# %%
check_points = np.arange(0,101,5)

# %%
year = 2009
beta = 0.02
model_param = 'L0.0001-B32-N5-E0.001'
#test_year(year,model_param,beta,check_points)
plot_year_beta(year,model_param,beta,check_points)
